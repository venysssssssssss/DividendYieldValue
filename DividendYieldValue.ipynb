# %% [markdown]
# <a href="https://colab.research.google.com/github/venysssssssssss/DividendYieldValue/blob/main/DividendYieldValue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. **Instalando e importando bibliotecas**

# %%
# !pip install yfinance --quiet

# %%
# !pip install vectorbt --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.4 MB/s eta 0:00:00

# %%
import vectorbt as vbt
import pandas as pd
import yfinance as yf

# %% [markdown]
# ## 2. ***Definir ações (papéis ou tijolos)***

# %%
tickers = ['BBAS3.SA', 'BBDC4.SA', 'ITUB4.SA', 'SANB11.SA', 'ABCB4.SA', 'BPAC11.SA', 'BRSR6.SA', 'BPAN4.SA', 'VGIR11.SA']

# %% [markdown]
# ## 3. ***Extraindo dados das ações***

# %%
div = vbt.YFData.download(tickers, start='2008-01-01').get('Dividends')
div.tail()
# Out:
# /usr/local/lib/python3.10/dist-packages/vectorbt/data/base.py:527: UserWarning: Symbols have mismatching index. Setting missing data points to NaN.
#   data = cls.align_index(data, missing=missing_index)
# symbol                     BBAS3.SA  BBDC4.SA  ITUB4.SA  SANB11.SA  ABCB4.SA  \
# Date
# 2023-07-28 03:00:00+00:00       0.0  0.000000   0.00000        0.0       0.0
# 2023-07-31 03:00:00+00:00       0.0  0.000000   0.00000        0.0       0.0
# 2023-08-01 03:00:00+00:00       0.0  0.000000   0.01765        0.0       0.0
# 2023-08-02 03:00:00+00:00       0.0  0.018975   0.00000        0.0       0.0
# 2023-08-04 03:00:00+00:00       0.0  0.000000   0.00000        0.0       0.0
#
# symbol                     BPAC11.SA  BRSR6.SA  BPAN4.SA  VGIR11.SA
# Date
# 2023-07-28 03:00:00+00:00        0.0       0.0       0.0        0.0
# 2023-07-31 03:00:00+00:00        0.0       0.0       0.0        0.0
# 2023-08-01 03:00:00+00:00        0.0       0.0       0.0        0.0
# ...

# %%
close = yf.download(tickers, start='2008-01-01')['Close']
close.tail()
# Out:
# [*********************100%***********************]  9 of 9 completed
#              ABCB4.SA   BBAS3.SA   BBDC4.SA  BPAC11.SA  BPAN4.SA  BRSR6.SA  \
# Date
# 2023-07-28  18.420000  47.279999  16.510000  33.840000      9.38     14.64
# 2023-07-31  18.700001  48.189999  16.660000  34.009998      9.30     14.59
# 2023-08-01  19.160000  47.360001  16.620001  33.799999      9.20     14.49
# 2023-08-02  19.070000  47.570000  16.670000  33.209999      9.18     14.47
# 2023-08-04  19.559999  47.540001  15.650000  33.080002      8.61     14.24
#
#              ITUB4.SA  SANB11.SA  VGIR11.SA
# Date
# 2023-07-28  28.540001  28.790001       9.48
# 2023-07-31  28.639999  28.559999       9.58
# 2023-08-01  28.709999  28.629999       9.60
# 2023-08-02  28.620001  28.510000       9.73
# 2023-08-04  28.139999  28.139999       9.83

# %% [markdown]
# ##4.  ***Padronizando os dados***

# %%
div.index = pd.to_datetime(div.index.date)
close.index = pd.to_datetime(close.index.date)

# %%
div = div.reindex(sorted(div.columns), axis=1)
close = close.reindex(sorted(close.columns), axis=1)

# %%
div.tail()
# Out:
# symbol      ABCB4.SA  BBAS3.SA  BBDC4.SA  BPAC11.SA  BPAN4.SA  BRSR6.SA  \
# 2023-07-28       0.0       0.0  0.000000        0.0       0.0       0.0
# 2023-07-31       0.0       0.0  0.000000        0.0       0.0       0.0
# 2023-08-01       0.0       0.0  0.000000        0.0       0.0       0.0
# 2023-08-02       0.0       0.0  0.018975        0.0       0.0       0.0
# 2023-08-04       0.0       0.0  0.000000        0.0       0.0       0.0
#
# symbol      ITUB4.SA  SANB11.SA  VGIR11.SA
# 2023-07-28   0.00000        0.0        0.0
# 2023-07-31   0.00000        0.0        0.0
# 2023-08-01   0.01765        0.0        0.0
# 2023-08-02   0.00000        0.0        0.0
# 2023-08-04   0.00000        0.0        0.0

# %%
close.tail()
# Out:
#              ABCB4.SA   BBAS3.SA   BBDC4.SA  BPAC11.SA  BPAN4.SA  BRSR6.SA  \
# 2023-07-28  18.420000  47.279999  16.510000  33.840000      9.38     14.64
# 2023-07-31  18.700001  48.189999  16.660000  34.009998      9.30     14.59
# 2023-08-01  19.160000  47.360001  16.620001  33.799999      9.20     14.49
# 2023-08-02  19.070000  47.570000  16.670000  33.209999      9.18     14.47
# 2023-08-04  19.559999  47.540001  15.650000  33.080002      8.61     14.24
#
#              ITUB4.SA  SANB11.SA  VGIR11.SA
# 2023-07-28  28.540001  28.790001       9.48
# 2023-07-31  28.639999  28.559999       9.58
# 2023-08-01  28.709999  28.629999       9.60
# 2023-08-02  28.620001  28.510000       9.73
# 2023-08-04  28.139999  28.139999       9.83

# %% [markdown]
# ##5.  ***Dividendo dos últimos 12 Meses***

# %%
div_12m = div.rolling('365D').sum()
div_12m.tail()
# Out:
# symbol      ABCB4.SA  BBAS3.SA  BBDC4.SA  BPAC11.SA  BPAN4.SA  BRSR6.SA  \
# 2023-07-28     1.568  3.166058  1.007999   0.657005  0.502678  0.880093
# 2023-07-31     1.568  3.166058  1.007999   0.657005  0.502678  0.880093
# 2023-08-01     1.568  3.166058  1.007999   0.657005  0.502678  0.880093
# 2023-08-02     1.568  3.166058  1.008000   0.657005  0.502678  0.880093
# 2023-08-04     1.568  3.166058  1.008000   0.657005  0.502678  0.880093
#
# symbol      ITUB4.SA  SANB11.SA  VGIR11.SA
# 2023-07-28   1.53278   2.178748        1.5
# 2023-07-31   1.53278   2.178748        1.5
# 2023-08-01   1.53278   2.178748        1.5
# 2023-08-02   1.53278   2.178748        1.5
# 2023-08-04   1.53278   2.178748        1.5

# %% [markdown]
# ##6.  ***Dividend Yield***

# %%
dy_12m = (div_12m/close) * 100
dy_12m.tail()
# Out:
# symbol      ABCB4.SA  BBAS3.SA  BBDC4.SA  BPAC11.SA  BPAN4.SA  BRSR6.SA  \
# 2023-07-28  8.512486  6.696400  6.105385   1.941504  5.359040  6.011564
# 2023-07-31  8.385026  6.569948  6.050414   1.931800  5.405140  6.032166
# 2023-08-01  8.183716  6.685089  6.064976   1.943802  5.463891  6.073796
# 2023-08-02  8.222339  6.655577  6.046791   1.978335  5.475795  6.082191
# 2023-08-04  8.016360  6.659777  6.440895   1.986109  5.838305  6.180428
#
# symbol      ITUB4.SA  SANB11.SA  VGIR11.SA
# 2023-07-28  5.370638   7.567725  15.822786
# 2023-07-31  5.351886   7.628670  15.657620
# 2023-08-01  5.338837   7.610018  15.624999
# 2023-08-02  5.355625   7.642048  15.416239
# 2023-08-04  5.446980   7.742530  15.259410

# %% [markdown]
# ## 7. ***Plot***

# %%
dy_12m.vbt.plot(width=1000, height=600).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
